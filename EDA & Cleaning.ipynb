# %% [markdown]
# # Exploratory Data Analysis

# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading the dataset
data = pd.read_csv("2015_Street_Tree_Census_-_Tree_Data.csv")

# %%
# reading top rows
data.head()
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common  ...  boro_ct  \
# 0                         Acer rubrum        red maple  ...  4073900
# 1                   Quercus palustris          pin oak  ...  4097300
# 2  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 3  Gleditsia triacanthos var. inermis      honeylocust  ...  3044900
# 4                     Tilia americana  American linden  ...  3016500
#
#       state   latitude  longitude         x_sp         y_sp council district  \
# ...

# %%
# display all the columns
pd.set_option('display.max_columns', None)

# display all the rows
# pd.set_option('display.max_rows', None)

# %%
data.head()
# displaying all thr columns
# Out:
#    tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status health  \
# 0   180683    348711  08/27/2015         3           0   OnCurb  Alive   Fair
# 1   200540    315986  09/03/2015        21           0   OnCurb  Alive   Fair
# 2   204026    218365  09/05/2015         3           0   OnCurb  Alive   Good
# 3   204337    217969  09/05/2015        10           0   OnCurb  Alive   Good
# 4   189565    223043  08/30/2015        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  \
# 0                         Acer rubrum        red maple    None   None
# 1                   Quercus palustris          pin oak    None   None
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2   None
# 3  Gleditsia triacanthos var. inermis      honeylocust    None   None
# 4                     Tilia americana  American linden    None   None
#
#    sidewalk         user_type problems root_stone root_grate root_other  \
# ...

# %% [markdown]
# As there are lot of columns we need to have a goal in mind to explore the dataset.
# Else we would be overwhelmed by the amount of columns.
# Here, we are aiming to just find the general health of the trees in the NYC.
# By doing that we can reduce the number of columns.

# %%
# reading all the columns
data.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
# Now, we can delete the columns that are not useful.
# First as we know we are exploring trees in whole of NY we can get rid of columns that gives locations.
data_subset = data[['tree_id', 'tree_dbh', 'stump_diam','curb_loc', 
                           'status', 'health', 'spc_latin', 'steward', 'sidewalk', 
                           'problems', 'root_stone','root_grate', 'root_other', 
                           'trunk_wire', 'trnk_light', 'trnk_other','brch_light',
                           'brch_shoe', 'brch_other']]
data_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
# checking for missing values.

data_subset.isna().sum()
# Out:
# tree_id           0
# tree_dbh          0
# stump_diam        0
# curb_loc          0
# status            0
# health        31616
# spc_latin     31619
# steward       31615
# sidewalk      31616
# problems      31664
# root_stone        0
# root_grate        0
# root_other        0
# trunk_wire        0
# trnk_light        0
# trnk_other        0
# brch_light        0
# brch_shoe         0
# brch_other        0
# dtype: int64

# %%
data_subset[data_subset['health'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 37       211205         0          16          OnCurb  Stump    NaN       NaN
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 239      203597         0          15          OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683695   170888         0           5          OnCurb  Stump    NaN       NaN
# 683697   177922         0          17          OnCurb  Stump    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
# 683699   172660         0           4          OnCurb  Stump    NaN       NaN
#
# ...

# %%
# describe the numeric values from the data set
data_subset.describe()

# both tree_dbh and stump_dbh is in inch so 450inch would be a big tree for a street-tree.
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683788.000000  683788.000000  683788.000000
# mean   365205.011085      11.279787       0.432463
# std    208122.092902       8.723042       3.290241
# min         3.000000       0.000000       0.000000
# 25%    186582.750000       4.000000       0.000000
# 50%    366214.500000       9.000000       0.000000
# 75%    546170.250000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
# visulize to get the idea of distribution
data_subset.hist(bins = 60, figsize = (20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'tree_id'}>,
#         <AxesSubplot:title={'center':'tree_dbh'}>],
#        [<AxesSubplot:title={'center':'stump_diam'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# getting the values where tree_dbh > 50inch 
big_trees = data_subset[data_subset['tree_dbh'] > 50]
big_trees
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2405     168583       425           0          OnCurb  Alive   Good
# 3738     199546        51           0          OnCurb  Alive   Good
# 4887     139665        72           0  OffsetFromCurb  Alive   Good
# 6724     209349       122           0          OnCurb  Alive   Good
# 10083    215075       169           0          OnCurb  Alive   Good
# ...         ...       ...         ...             ...    ...    ...
# 675265   179496        52           0  OffsetFromCurb  Alive   Good
# 677954   166796        54           0          OnCurb  Alive   Good
# 679894   169501        51           0          OnCurb  Alive   Good
# 681736   179366       281           0          OnCurb  Alive   Fair
# 682788   183910       127           0          OnCurb   Dead    NaN
#
#                                  spc_latin steward  sidewalk      problems  \
# ...

# %%
# big_trees has all the points that have tree_dbh > 50.

big_trees.plot(kind = 'scatter', x = 'tree_id', y = 'tree_dbh', figsize = (10, 8))

# we visualize through a scatter plot to identify the distibution.
# it is visible that after 300 mark there are hardly 3-4 trees.
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='tree_dbh'>

# %%
# repeating the same process for tree stump.
big_stumps = data_subset[data_subset['stump_diam'] > 50]
big_stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 6122     200925         0          52   OnCurb  Stump    NaN       NaN
# 6177     200924         0          55   OnCurb  Stump    NaN       NaN
# 6466     166008         0          72   OnCurb  Stump    NaN       NaN
# 7042     206818         0         100   OnCurb  Stump    NaN       NaN
# 9872     192215         0          53   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 645994   135904         0          65   OnCurb  Stump    NaN       NaN
# 646336   151125         0          55   OnCurb  Stump    NaN       NaN
# 649174   154188         0          65   OnCurb  Stump    NaN       NaN
# 652690   154181         0          60   OnCurb  Stump    NaN       NaN
# 653066   154190         0          80   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
# Scatter plot visualisation for stump.
big_stumps.plot(kind = 'scatter', x = 'tree_id', y = 'stump_diam', figsize = (10, 8))

# we can observe that up until 60inch there is quite density in values but after that it thins out.
# After 100 mark there are hardly 10 values.
# Out:
# <AxesSubplot:xlabel='tree_id', ylabel='stump_diam'>

# %% [markdown]
# It could be an error on the part of survey that they might have enter circumference instead of diameter.
# As 450inch and 140inch for diameter for street tree is too big.

# %%
data_subset[data_subset['stump_diam'] > 100]
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 11342    206819         0         140   OnCurb  Stump    NaN       NaN
# 67831    253992         0         118   OnCurb  Stump    NaN       NaN
# 73377    278733         0         109   OnCurb  Stump    NaN       NaN
# 89539    286364         0         134   OnCurb  Stump    NaN       NaN
# 137315   319640         0         131   OnCurb  Stump    NaN       NaN
# 267239   484857         0         115   OnCurb  Stump    NaN       NaN
# 399840   624806         0         107   OnCurb  Stump    NaN       NaN
# 420332   638508         0         104   OnCurb  Stump    NaN       NaN
# 497829   711302         0         125   OnCurb  Stump    NaN       NaN
# 543264    35364         0         120   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# 11342      NaN      NaN      NaN         No         No         No         No
# ...

# %%
# identifying the different types of names.

data_subset['spc_latin'].value_counts()

# there are a total of 132 different species
# Out:
# Platanus x acerifolia                 87014
# Gleditsia triacanthos var. inermis    64264
# Pyrus calleryana                      58931
# Quercus palustris                     53185
# Acer platanoides                      34189
#                                       ...
# Pinus nigra                              37
# Pinus rigida                             33
# Maclura pomifera                         29
# Pinus sylvestris                         25
# Pinus virginiana                         10
# Name: spc_latin, Length: 132, dtype: int64

# %%
# using pd.DataFrame to convert to pamdas dataframe.
pd.DataFrame(data_subset['spc_latin'].value_counts())

# using bar graph to plot the different species.
# The visualization is not very readable but we can get a rough idea about the commion and rare trees.
pd.DataFrame(data_subset['spc_latin'].value_counts()).plot(kind = 'bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
# identifying the different categories
data_subset['steward'].value_counts()
# Out:
# None       487823
# 1or2       143557
# 3or4        19183
# 4orMore      1610
# Name: steward, dtype: int64

# %%
# identifying the different categories
data_subset['sidewalk'].value_counts()
# Out:
# NoDamage    464978
# Damage      187194
# Name: sidewalk, dtype: int64

# %%
# identifying the different categories
data_subset['status'].value_counts()
# Out:
# Alive    652173
# Stump     17654
# Dead      13961
# Name: status, dtype: int64

# %%
# identifying the different categories
data_subset['curb_loc'].value_counts()
# Out:
# OnCurb            656896
# OffsetFromCurb     26892
# Name: curb_loc, dtype: int64

# %%
# Number of trees with status = stumps , 17654
stumps = data_subset[data_subset['status'] == 'Stump']
stumps
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 37       211205         0          16   OnCurb  Stump    NaN       NaN
# 239      203597         0          15   OnCurb  Stump    NaN       NaN
# 641      179766         0          30   OnCurb  Stump    NaN       NaN
# 644      180619         0          10   OnCurb  Stump    NaN       NaN
# 646      208828         0          15   OnCurb  Stump    NaN       NaN
# ...         ...       ...         ...      ...    ...    ...       ...
# 683348   152836         0          13   OnCurb  Stump    NaN       NaN
# 683686   191219         0          25   OnCurb  Stump    NaN       NaN
# 683695   170888         0           5   OnCurb  Stump    NaN       NaN
# 683697   177922         0          17   OnCurb  Stump    NaN       NaN
# 683699   172660         0           4   OnCurb  Stump    NaN       NaN
#
#        steward sidewalk problems root_stone root_grate root_other trunk_wire  \
# ...

# %%
# Number of trees with status = dead, 13961
dead = data_subset[data_subset['status'] == 'Dead']
dead
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health spc_latin  \
# 57       187807         0           0          OnCurb   Dead    NaN       NaN
# 196      208322        10           0          OnCurb   Dead    NaN       NaN
# 209      209058         6           0          OnCurb   Dead    NaN       NaN
# 266      210544         6           0          OnCurb   Dead    NaN       NaN
# 285      188609         9           0          OnCurb   Dead    NaN       NaN
# ...         ...       ...         ...             ...    ...    ...       ...
# 682816   184342        11           0          OnCurb   Dead    NaN       NaN
# 682823   155430         2           0          OnCurb   Dead    NaN       NaN
# 683346   156566        10           0          OnCurb   Dead    NaN       NaN
# 683693   156162         3           0  OffsetFromCurb   Dead    NaN       NaN
# 683698   193791         3           0          OnCurb   Dead    NaN       NaN
#
# ...

# %% [markdown]
# We can see that when the status is stump or dead surveyors did not fill these columns:
#
# health        31616
#
# spc_latin     31619
#
# steward       31615
#
# sidewalk      31616
#
# problems      31664
#
# So, it turned out as missing value in our original examination.
# 17654 + 13961 = 31615

# %%
# Now, we check how the probles are distibuted in the tree.
problems = data_subset[['root_stone','root_grate', 'root_other', 
                           'trunk_wire', 'trnk_light', 'trnk_other','brch_light',
                           'brch_shoe', 'brch_other']]
problems
# Out:
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 0              No         No         No         No         No         No
# 1             Yes         No         No         No         No         No
# 2              No         No         No         No         No         No
# 3             Yes         No         No         No         No         No
# 4             Yes         No         No         No         No         No
# ...           ...        ...        ...        ...        ...        ...
# 683783         No         No         No         No         No         No
# 683784         No         No         No         No         No         No
# 683785         No         No         No         No         No         No
# 683786         No         No         No         No         No         No
# 683787         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 0              No        No         No
# ...

# %%
# now to see the distibution we apply the series function.
problems.apply(pd.Series.value_counts)

# We can see that root stone is one of the most common probles in the trees.
# Out:
#      root_stone  root_grate  root_other  trunk_wire  trnk_light  trnk_other  \
# No       543789      680252      653466      670514      682757      651215
# Yes      139999        3536       30322       13274        1031       32573
#
#      brch_light  brch_shoe  brch_other
# No       621423     683377      659433
# Yes       62365        411       24355

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Removed Column that was not needed.
#
# Checked for non-standard values in the categorical columns.

# %% [markdown]
# We observed during exploration stage that trees that are not alive or are stump have few information missing. So we should remove trees that are not alive.
#
# An easier way is to remove trees that are alive.
#
# Instead of removing missing values we can change them to 'Not Applicable' as health of a stump or a dead is not important.

# %%
# creating a mask/variable containing only stump and dead trees.
mask = ((data_subset['status'] == 'Stump') | (data_subset['status'] == 'Dead'))
# mask = data_subset['status'] != 'Alive'

# %%
data_subset.loc[mask] = data_subset.loc[mask].fillna('Not Applicable')
# Out:
# C:\Users\krjos\anaconda3\lib\site-packages\pandas\core\indexing.py:1884: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %%
data_subset[data_subset['status'] == 'Stump']
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status          health  \
# 37       211205         0          16   OnCurb  Stump  Not Applicable
# 239      203597         0          15   OnCurb  Stump  Not Applicable
# 641      179766         0          30   OnCurb  Stump  Not Applicable
# 644      180619         0          10   OnCurb  Stump  Not Applicable
# 646      208828         0          15   OnCurb  Stump  Not Applicable
# ...         ...       ...         ...      ...    ...             ...
# 683348   152836         0          13   OnCurb  Stump  Not Applicable
# 683686   191219         0          25   OnCurb  Stump  Not Applicable
# 683695   170888         0           5   OnCurb  Stump  Not Applicable
# 683697   177922         0          17   OnCurb  Stump  Not Applicable
# 683699   172660         0           4   OnCurb  Stump  Not Applicable
#
#              spc_latin         steward        sidewalk        problems  \
# ...

# %%
#checking the missing values now.
data_subset.isna().sum()
# Out:
# tree_id        0
# tree_dbh       0
# stump_diam     0
# curb_loc       0
# status         0
# health         1
# spc_latin      5
# steward        0
# sidewalk       1
# problems      49
# root_stone     0
# root_grate     0
# root_other     0
# trunk_wire     0
# trnk_light     0
# trnk_other     0
# brch_light     0
# brch_shoe      0
# brch_other     0
# dtype: int64

# %% [markdown]
# As we treated the values realting to Stump or Dead with 'Not Applicable' now the values that are remaining are actually missing values.
# As we see the missing values are very less we can opt to drop them.
# Or we can do mode imputation.

# %%
data_subset[data_subset['health'].isna()]
# Out:
#        tree_id  tree_dbh  stump_diam curb_loc status health  \
# 32889   245041        16           0   OnCurb  Alive    NaN
#
#                     spc_latin steward sidewalk problems root_stone root_grate  \
# 32889  Fraxinus pennsylvanica    None   Damage     None         No         No
#
#       root_other trunk_wire trnk_light trnk_other brch_light brch_shoe  \
# 32889         No         No         No         No         No        No
#
#       brch_other
# 32889         No

# %%
data_subset['health'].value_counts()
# Out:
# Good              528850
# Fair               96504
# Not Applicable     31615
# Poor               26818
# Name: health, dtype: int64

# %%
data_subset[data_subset['spc_latin'].isna()]

# As this column refers to the latin name of the tree it would be better drop this as 5 rows won't make much of a difference.
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health spc_latin  \
# 356613   562532         4           0   OnCurb  Alive   Good       NaN
# 427541   630814        11           0   OnCurb  Alive   Poor       NaN
# 431417   651014        40           0   OnCurb  Alive   Good       NaN
# 608632    47941         5           0   OnCurb  Alive   Good       NaN
# 656960   150745         3           0   OnCurb  Alive   Good       NaN
#
#        steward  sidewalk problems root_stone root_grate root_other trunk_wire  \
# 356613    1or2  NoDamage   Stones        Yes         No         No         No
# 427541    None    Damage      NaN         No         No         No         No
# 431417    None    Damage   Stones        Yes         No         No         No
# 608632    1or2  NoDamage     None         No         No         No         No
# 656960    1or2    Damage     None         No         No         No         No
#
#        trnk_light trnk_other brch_light brch_shoe brch_other
# ...

# %%
data_subset[data_subset['sidewalk'].isna()]
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 346299   540677         7           0  OffsetFromCurb  Alive   Good
#
#                                  spc_latin steward sidewalk problems  \
# 346299  Gleditsia triacanthos var. inermis    None      NaN     None
#
#        root_stone root_grate root_other trunk_wire trnk_light trnk_other  \
# 346299         No         No         No         No         No         No
#
#        brch_light brch_shoe brch_other
# 346299         No        No         No

# %%
data_subset['sidewalk'].value_counts()
# Out:
# NoDamage          464978
# Damage            187194
# Not Applicable     31615
# Name: sidewalk, dtype: int64

# %%
data_subset[data_subset['problems'].isna()]
# now for problems we can replace with none as other disease column says 'No'.
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 120289   332668        30           0  OffsetFromCurb  Alive   Fair
# 121488   332669        28           0  OffsetFromCurb  Alive   Fair
# 121685   332670        24           0  OffsetFromCurb  Alive   Fair
# 133470   332693        11           0  OffsetFromCurb  Alive   Good
# 133812   332692        15           0  OffsetFromCurb  Alive   Good
# 134820   332694        28           0  OffsetFromCurb  Alive   Good
# 144137   332947         3           0          OnCurb  Alive   Good
# 145324   332543         9           0          OnCurb  Alive   Good
# 145337   332541         8           0          OnCurb  Alive   Good
# 146314   332542         8           0          OnCurb  Alive   Good
# 146378   332950         3           0          OnCurb  Alive   Good
# 146430   332949         3           0          OnCurb  Alive   Good
# 146630   332948         3           0          OnCurb  Alive   Good
# ...

# %%
data_subset['problems'].value_counts()
# Out:
# None                                                                          426280
# Stones                                                                         95673
# Not Applicable                                                                 31615
# BranchLights                                                                   29452
# Stones,BranchLights                                                            17808
#                                                                                ...
# Stones,RootOther,WiresRope,TrunkLights,TrunkOther,BranchLights,BranchOther         1
# Stones,MetalGrates,TrunkLights,TrunkOther                                          1
# MetalGrates,RootOther,TrunkLights,BranchLights                                     1
# WiresRope,TrunkOther,BranchLights,Sneakers                                         1
# MetalGrates,TrunkOther,Sneakers                                                    1
# Name: problems, Length: 233, dtype: int64

# %%
data_subset['health'].fillna('Good', inplace = True)
data_subset['sidewalk'].fillna('NoDamage', inplace = True)
data_subset['problems'].fillna('None', inplace = True)
# Out:
# C:\Users\krjos\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
data_subset.isna().sum()
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     5
# steward       0
# sidewalk      0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %%
data_subset
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %%
data_subset.dropna(inplace = True)

# dropped 5 values from spc_latin
# Out:
# C:\Users\krjos\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
data_subset.isna().sum()
# no missing values
# Out:
# tree_id       0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_latin     0
# steward       0
# sidewalk      0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trunk_wire    0
# trnk_light    0
# trnk_other    0
# brch_light    0
# brch_shoe     0
# brch_other    0
# dtype: int64

# %% [markdown]
# checking for outliers in the stump and tree diameters

# %%
data_subset.describe()
# Out:
#              tree_id       tree_dbh     stump_diam
# count  683783.000000  683783.000000  683783.000000
# mean   365204.693703      11.279777       0.432466
# std    208121.666901       8.722992       3.290253
# min         3.000000       0.000000       0.000000
# 25%    186583.500000       4.000000       0.000000
# 50%    366214.000000       9.000000       0.000000
# 75%    546168.500000      16.000000       0.000000
# max    722694.000000     450.000000     140.000000

# %%
Q1t = data_subset['tree_dbh'].quantile(0.25)
Q3t = data_subset['tree_dbh'].quantile(0.75)
IQRt = Q3t - Q1t # 12
LBt = Q1t - (1.5 * IQRt) 
UBt = Q3t + (1.5 * IQRt)

print(LBt, UBt, IQRt)

# data_subset = ((data_subset['tree_dbh'] >= LB) & (data_subset['tree_dbh'] <= UB))

# From the IQR we can see that trees having diameter greater than 34inch are outlier.
# Also we are getting lower range as -14 which cannot be possible.
# So we will not be using IQR for outlier detection.
# Out:
# -14.0 34.0 12.0

# %%
plt.figure(figsize = (10,8))
data_subset.boxplot(column = ['tree_dbh'])
# Out:
# <AxesSubplot:>

# %%
Q1s = data_subset['stump_diam'].quantile(0.25)
Q3s = data_subset['stump_diam'].quantile(0.75)
IQRs = Q3s - Q1s 
LBs = Q1s - (1.5 * IQRs) 
UBs = Q3s + (1.5 * IQRs)

print(LBs,UBs, IQRs)
# As the stump value for the living tree is 0, only 17654 value comes out not to be 0.
# So we cannot use IQR for the outlier detection in stump.
# Out:
# 0.0 0.0 0.0

# %%
plt.figure(figsize = (10,8))
data_subset.boxplot(column = ['stump_diam'])
# Out:
# <AxesSubplot:>

# %%
data_subset1 = data_subset[data_subset['tree_dbh'] > 34]
data_subset1
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 44       193690        36           0   OnCurb  Alive   Good
# 75       196080        36           0   OnCurb  Alive   Good
# 83       203550        42           0   OnCurb  Alive   Good
# 96       203592        38           0   OnCurb  Alive   Good
# 116      208456        36           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683366   179986        36           0   OnCurb  Alive   Good
# 683391   201402        47           0   OnCurb  Alive   Good
# 683403   191598        37           0   OnCurb  Alive   Good
# 683475   184193        38           0   OnCurb  Alive   Good
# 683476   184194        38           0   OnCurb  Alive   Good
#
#                     spc_latin steward  sidewalk             problems  \
# 44      Platanus x acerifolia    None    Damage               Stones
# 75      Platanus x acerifolia    None  NoDamage  Stones,BranchLights
# ...

# %%
big_trees = data_subset[(data_subset['tree_dbh'] > 60) | (data_subset['stump_diam'] > 60)]
big_trees

# big_trees returns all the trees and stump with diameter > 60
# That equals to a total of 245 trees 
# we would consider this as outlier.
# because if we go by IQR method, any tree anove 34inch is an outlier which may not be veery realistic.
# which gives 10257 trees as outliers so if we want we can drop that as it is only 1.5% of the dataset.
# Out:
#         tree_id  tree_dbh  stump_diam        curb_loc status          health  \
# 2405     168583       425           0          OnCurb  Alive            Good
# 4887     139665        72           0  OffsetFromCurb  Alive            Good
# 6466     166008         0          72          OnCurb  Stump  Not Applicable
# 6724     209349       122           0          OnCurb  Alive            Good
# 7042     206818         0         100          OnCurb  Stump  Not Applicable
# ...         ...       ...         ...             ...    ...             ...
# 667425   151958        66           0  OffsetFromCurb  Alive            Fair
# 673105   165324        79           0          OnCurb  Alive            Good
# 674016   184879       105           0          OnCurb  Alive            Fair
# 681736   179366       281           0          OnCurb  Alive            Fair
# 682788   183910       127           0          OnCurb   Dead  Not Applicable
#
# ...

# %% [markdown]
# Instead of dropping these 245 rowswe can impute it with the type of tree having the mean or max diameter.

# %%
data_subset = data_subset[(data_subset['tree_dbh'] <= 60) & (data_subset['stump_diam'] <= 60)]
data_subset

# filtering main dataset with the outlier values to find the mean value.
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683         3           0   OnCurb  Alive   Fair
# 1        200540        21           0   OnCurb  Alive   Fair
# 2        204026         3           0   OnCurb  Alive   Good
# 3        204337        10           0   OnCurb  Alive   Good
# 4        189565        21           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 683783   155433        25           0   OnCurb  Alive   Good
# 683784   183795         7           0   OnCurb  Alive   Good
# 683785   166161        12           0   OnCurb  Alive   Good
# 683786   184028         9           0   OnCurb  Alive   Good
# 683787   200607        23           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...

# %% [markdown]
# we would also need different dataset for dead/stump and alive trees as the value for both are different.

# %%
# we would also need different dataset for dead/stump and alive trees as the value for both are different.

data_subset_alive = data_subset[data_subset['status'] == 'Alive']
data_subset_dead_or_stump = data_subset[(data_subset['status'] == 'Dead') | (data_subset['status'] == 'Stump')]

# %%
# grouping the dataset by the type of tree.

data_subset_alive.groupby('spc_latin')['tree_dbh'].describe()
# Out:
#                      count       mean       std  min  25%   50%   75%   max
# spc_latin
# Acer                7080.0  11.675424  6.577626  0.0  7.0  11.0  15.0  59.0
# Acer buergerianum    110.0   8.090909  4.544470  2.0  5.0   8.0  10.0  28.0
# Acer campestre      2549.0   7.103962  4.293100  0.0  4.0   6.0   9.0  35.0
# Acer ginnala        2049.0   7.869204  4.853365  0.0  4.0   7.0  10.0  40.0
# Acer griseum         220.0   3.509091  3.578846  1.0  2.0   2.0   3.0  30.0
# ...                    ...        ...       ...  ...  ...   ...   ...   ...
# Tsuga canadensis      88.0   5.193182  3.959153  0.0  2.0   3.5   7.0  21.0
# Ulmus americana     7972.0  11.933768  9.374470  0.0  4.0   9.0  17.0  58.0
# Ulmus parvifolia    5344.0   7.396894  5.669532  0.0  3.0   5.0  10.0  53.0
# Ulmus pumila        1593.0  11.305712  8.665334  1.0  4.0   9.0  17.0  58.0
# Zelkova serrata    29253.0   7.842478  5.006273  0.0  4.0   6.0  11.0  58.0
#
# [132 rows x 8 columns]

# %% [markdown]
# Now we have encountered a new issue.
# We can see that min value is 0 which is not possible.
# SO, to rectify this situation we will set boundaries.
# We only need value lower that 25%ile and higher than 75%ile.
#
# or we can impute the 0 to mean values.
#
# We will go with first as it is more interesting.

# %%
stats = data_subset_alive.groupby('spc_latin')['tree_dbh'].describe().reset_index()[['spc_latin', '25%', '75%']]
stats
# resetting index to spc_latin
# Out:
#              spc_latin  25%   75%
# 0                 Acer  7.0  15.0
# 1    Acer buergerianum  5.0  10.0
# 2       Acer campestre  4.0   9.0
# 3         Acer ginnala  4.0  10.0
# 4         Acer griseum  2.0   3.0
# ..                 ...  ...   ...
# 127   Tsuga canadensis  2.0   7.0
# 128    Ulmus americana  4.0  17.0
# 129   Ulmus parvifolia  3.0  10.0
# 130       Ulmus pumila  4.0  17.0
# 131    Zelkova serrata  4.0  11.0
#
# [132 rows x 3 columns]

# %%
# mergeing the new dataset(stats) with the original(data_subset_alive)

data_subset_alive = data_subset_alive.merge(stats, on= 'spc_latin', how= 'left')

# %%
data_subset_alive.head()
# Out:
#    tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0   180683         3           0   OnCurb  Alive   Fair
# 1   200540        21           0   OnCurb  Alive   Fair
# 2   204026         3           0   OnCurb  Alive   Good
# 3   204337        10           0   OnCurb  Alive   Good
# 4   189565        21           0   OnCurb  Alive   Good
#
#                             spc_latin steward  sidewalk problems root_stone  \
# 0                         Acer rubrum    None  NoDamage     None         No
# 1                   Quercus palustris    None    Damage   Stones        Yes
# 2  Gleditsia triacanthos var. inermis    1or2    Damage     None         No
# 3  Gleditsia triacanthos var. inermis    None    Damage   Stones        Yes
# 4                     Tilia americana    None    Damage   Stones        Yes
#
#   root_grate root_other trunk_wire trnk_light trnk_other brch_light brch_shoe  \
# 0         No         No         No         No         No         No        No
# ...

# %%
# dataframe.loc[]: Access a group of rows and columns by label(s)

# Setting the tree_dbh as the 25% or 75% if it is out of bounds accordingly

cond = data_subset_alive['tree_dbh'] < data_subset_alive['25%'] 
#if tree diameter is smaller than 25% column, add to cond.
data_subset_alive.loc[cond, 'tree_dbh'] = data_subset_alive['25%']
#if cond is true then dbh = 25% column value.

cond = data_subset_alive['tree_dbh'] > data_subset_alive['75%']
data_subset_alive.loc[cond, 'tree_dbh'] = data_subset_alive['75%']

# %%
# Seems all the issues are resolved.
# And we finally have the dataset with the all the trees that are alive.

data_subset_alive
# Out:
#         tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0        180683       5.0           0   OnCurb  Alive   Fair
# 1        200540      21.0           0   OnCurb  Alive   Fair
# 2        204026       6.0           0   OnCurb  Alive   Good
# 3        204337      10.0           0   OnCurb  Alive   Good
# 4        189565      12.0           0   OnCurb  Alive   Good
# ...         ...       ...         ...      ...    ...    ...
# 652013   155433      24.0           0   OnCurb  Alive   Good
# 652014   183795       5.0           0   OnCurb  Alive   Good
# 652015   166161      12.0           0   OnCurb  Alive   Good
# 652016   184028       9.0           0   OnCurb  Alive   Good
# 652017   200607      14.0           0   OnCurb  Alive   Fair
#
#                                  spc_latin steward  sidewalk problems  \
# 0                              Acer rubrum    None  NoDamage     None
# 1                        Quercus palustris    None    Damage   Stones
# ...
